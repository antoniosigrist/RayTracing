# %% [markdown]
# ## Insira abaixo a saída de tempo obtida nos seus testes

# %% [markdown]
# #### Caso o primeiro teste realizado não tenha sido o de uma thread, altere o valor do first_test_num_threads

# %%
first_test_num_threads = 1

### Abaixo cole o tempo retorno para qualquer que tenha sido o tamanho da imagem utilizada.
time = [24.7289,
14.4734,
13.6823,
13.7496,
14.3514,
13.5364,
14.4948,
15.1864,
16.4197,
15.833,
15.5894,
16.3408,
18.0387,
16.1005,
17.0539,
16.0609,
16.2932,
17.05,
17.5058,
19.1951]

# %%
numthreads = []
for i in range (first_test_num_threads,len(time)+1):
    numthreads.append(i)

# %%
import matplotlib.pyplot as plt
plt.plot(numthreads,time,"o")
plt.title("Tempo x Número de Threads")
plt.ylabel('time (sec)')
plt.xlabel('Number of threads')
plt.show()

# %%
## Lista inserida manualmente a partir do monitor de atividade

gasto_memoria_kb = [
504,
588,
656,
720,
768,
836,
892,
948,
1000,
1131,
1172,
1193,
1201,
1222,
1320,
1379,
1421,
1480,
1530,
1590
]

# %%
plt.plot(numthreads,gasto_memoria_kb,"o")
plt.title("Memória x Número de Threads")
plt.ylabel('Memória usada (kB)')
plt.xlabel('Number of threads')
plt.show()

# %%
from scipy.stats import linregress

linregress(numthreads,gasto_memoria_kb)
# Out:
# LinregressResult(slope=55.18270676691729, intercept=498.13157894736844, rvalue=0.9954259850926831, pvalue=8.185873665609914e-20, stderr=1.2483155276048692)
